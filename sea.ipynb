# %% [markdown]
# Devido à ao mal planejamento quanto ao uso de um  <i>envirement<i> apropriado, precisou-se instalar-se a biblioteca Seaborn de uma maneira não usual que tornou-se intrusiva em meio ao notebook.

# %%
#import pip
#pip.main(['install','seaborn'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# #### Vamos iniciar dando atenção à alguns datasets, como: "car_crashes" e "tips"

# %%
tips = sns.load_dataset("tips")
crashes = sns.load_dataset("car_crashes")
iris = sns.load_dataset("iris")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data=tips,x="tip",y='total_bill',hue='day',size="size")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %% [markdown]
# #### Alguns pontos iniciais:
# Considerando que todas as gorjetas são pagas em dólares
# - Há uma predominância de gorjetas abaixo de $4 nos sábados
# - Entre "$3" e "$6" percebe-se uma predominância de gorjetas aos domingos
# - Sábado é o único dia, para este escopo, que rentabiliza gorjetas acima de $7

# %% [markdown]
# ### Explorando histogramas e gráficos distributivos no DataSet Iris

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #### Como o tamanho da pétala varia nas diferentes espécies de <i>iris<i>

# %%
sns.histplot(data=iris,x=iris['petal_length'],kde=True)
plt.title("Tamanho de pétalas (cm)")
# Out:
# Text(0.5, 1.0, 'Tamanho de pétalas (cm)')

# %%
sns.histplot(data=iris,x=iris['petal_length'],hue=iris['species'],kde=True)
plt.title("Tamanho de pétalas (cm) por espécies")
# Out:
# Text(0.5, 1.0, 'Tamanho de pétalas (cm) por espécies')

# %%
#Kernel Density Plot - Histograma suavizado
sns.kdeplot(data=iris['petal_length'],fill=True)
# Out:
# <Axes: xlabel='petal_length', ylabel='Density'>

# %% [markdown]
#  Percebe-se que a linha evidenciada no histograma anterior se mantem no gráfico KDE. Há uma relação de pétalas de, aproximadamente, 1cm e de 5cm em um maior número de espécimes

# %% [markdown]
# #### Vamos agora visualizar isso em um _JointPlot_ que correlacionará, não apenas, o tamanho das pétalas já visto, mas também a largura das sépalas:
# - Esse Joitplot pode ser resumido em um 2D KDEplot

# %%
sns.jointplot(x=iris['petal_length'],y=iris['sepal_width'],kind="kde")
