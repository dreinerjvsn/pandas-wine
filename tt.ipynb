# %%
import pandas as pd

# %%
reviews = pd.read_csv("/data/winemag-data-130k-v2.csv",index_col=0)
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# 1                                     Avidagos      87   15.0
# 2                                          NaN      87   14.0
# 3                         Reserve Late Harvest      87   13.0
# 4           Vintner's Reserve Wild Child Block      87   65.0
# ...                                        ...     ...    ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0
# 129967                                     NaN      90   75.0
# 129968                                   Kritt      90   30.0
# 129969                                     NaN      90   32.0
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0
#
#                  province             region_1           region_2  \
# 0       Sicily & Sardinia                 Etna                NaN
# 1                   Douro                  NaN                NaN
# 2                  Oregon    Willamette Valley  Willamette Valley
# 3                Michigan  Lake Michigan Shore                NaN
# 4                  Oregon    Willamette Valley  Willamette Valley
# ...                   ...                  ...                ...
# 129966              Mosel                  NaN                NaN
# 129967             Oregon               Oregon       Oregon Other
# 129968             Alsace               Alsace                NaN
# 129969             Alsace               Alsace                NaN
# 129970             Alsace               Alsace                NaN
#
#                taster_name taster_twitter_handle  \
# 0            Kerin O’Keefe          @kerinokeefe
# 1               Roger Voss            @vossroger
# 2             Paul Gregutt           @paulgwine
# 3       Alexander Peartree                   NaN
# 4             Paul Gregutt           @paulgwine
# ...                    ...                   ...
# 129966  Anna Lee C. Iijima                   NaN
# 129967        Paul Gregutt           @paulgwine
# 129968          Roger Voss            @vossroger
# 129969          Roger Voss            @vossroger
# 129970          Roger Voss            @vossroger
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# ...                                                   ...             ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...        Riesling
# 129967                  Citation 2004 Pinot Noir (Oregon)      Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                                           winery
# 0                                        Nicosia
# 1                            Quinta dos Avidagos
# 2                                      Rainstorm
# 3                                     St. Julian
# 4                                   Sweet Cheeks
# ...                                          ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967                                  Citation
# 129968                           Domaine Gresser
# 129969                      Domaine Marcel Deiss
# 129970                          Domaine Schoffit
#
# [129971 rows x 13 columns]

# %% [markdown]
# #### Melhor vinho pelo preço registrado

# %%
bargain = (reviews.points / reviews.price).idxmax()
out = reviews.loc[bargain,"title"]
out
# Out:
# 'Bandit NV Merlot (California)'

# %% [markdown]
# #### Contagem de palavras específicas ("tropical" e "fruity") encontradas em descrições de vinhos

# %%
def contaPalavra(palavra):
    count = 0
    for txt in reviews['description']:
        if palavra in txt:
            count += 1
    return count;
    
trop = contaPalavra("tropical")
frt = contaPalavra("fruity")
print(trop,frt)

descriptor_counts = pd.Series({"tropical": trop,"fruity":frt})
descriptor_counts
# Out:
# 3607 9090
# tropical    3607
# fruity      9090
# dtype: int64

# %% [markdown]
# #### Fazendo um Series que represente uma nova pontuação

# %%
def atribuirPontuacao(linha):    
    if linha["country"] == "Canada":
        return 3;
    elif linha["points"] >= 95:
        return 3;
    elif linha['points'] >= 85 & linha['points'] < 95:
        return 2;
    else:
        return 1;

rating = reviews.apply(atribuirPontuacao, axis=1)
rating
# Out:
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2
#          ..
# 129966    2
# 129967    2
# 129968    2
# 129969    2
# 129970    2
# Length: 129971, dtype: int64

# %%
sumarizacao = reviews.groupby('price').points.max()
sumarizacao.idxmax()
reviews[reviews['points']==sumarizacao.idxmax()]
# Out:
#           country                                        description  \
# 344         Chile  Aromas of pumpkin, squash and corn chips are s...
# 3640     Portugal  Aromas of strawberry sherbet are followed by s...
# 3641        Chile  Fluffy, sweet aromas of peach, pear and vanill...
# 4556        Italy  There's a thorny, almost raw quality of fruit ...
# 4557        Spain  With dusty, candied aromas, the bouquet on thi...
# ...           ...                                                ...
# 128258         US  This Chardonnay-Viognier blend is slightly swe...
# 128259         US  While there's some nice, honest fruit here, it...
# 128260         US  Banana, clove and orange peel open for this sw...
# 128261         US  Short and slightly sweet, there's nutty overto...
# 128262  Argentina  Smells like crushed vitamins, iron and mineral...
#
#                  designation  points  price          province  \
# 344             Gran Reserva      80   19.0      Leyda Valley
# 3640                 Estreia      80    8.0       Vinho Verde
# 3641                 Reserve      80   15.0      Maule Valley
# 4556               Rondineto      80   12.0     Central Italy
# 4557                Demi Sec      80   14.0         Catalonia
# ...                      ...     ...    ...               ...
# 128258      Devil's Daughter      80   25.0        California
# 128259                   NaN      80   14.0          Missouri
# 128260          Lucky Twenty      80   12.0          Colorado
# 128261  Proprietor's Reserve      80   13.0      Pennsylvania
# 128262      Finca La Martina      80   13.0  Mendoza Province
#
#                    region_1       region_2        taster_name  \
# 344                     NaN            NaN  Michael Schachner
# 3640                    NaN            NaN         Roger Voss
# 3641                    NaN            NaN  Michael Schachner
# 4556         Colli Aprutini            NaN                NaN
# 4557                   Cava            NaN  Michael Schachner
# ...                     ...            ...                ...
# 128258  Contra Costa County  Central Coast                NaN
# 128259             Missouri            NaN                NaN
# 128260             Colorado            NaN                NaN
# 128261         Pennsylvania            NaN                NaN
# 128262              Mendoza            NaN  Michael Schachner
#
#        taster_twitter_handle  \
# 344              @wineschach
# 3640              @vossroger
# 3641             @wineschach
# 4556                     NaN
# 4557             @wineschach
# ...                      ...
# 128258                   NaN
# 128259                   NaN
# 128260                   NaN
# 128261                   NaN
# 128262           @wineschach
#
#                                                     title          variety  \
# 344     Viña Tarapacá 2015 Gran Reserva Chardonnay (Le...       Chardonnay
# 3640            Viniverde 2011 Estreia Rosé (Vinho Verde)             Rosé
# 3641    Cuevas del Sur 2010 Reserve Chardonnay (Maule ...       Chardonnay
# 4556    Fattoria Giuseppe Savini 2011 Rondineto Merlot...           Merlot
# 4557            Paul Cheneau NV Demi Sec Sparkling (Cava)  Sparkling Blend
# ...                                                   ...              ...
# 128258  Bloomfield 2008 Devil's Daughter White (Contra...      White Blend
# 128259               Montelle 2008 Chambourcin (Missouri)      Chambourcin
# 128260         BookCliff NV Lucky Twenty White (Colorado)      White Blend
# 128261  Chaddsford 2007 Proprietor's Reserve White (Pe...      White Blend
# 128262  Reyter 2009 Finca La Martina Chardonnay (Mendoza)       Chardonnay
#
#                           winery
# 344                Viña Tarapacá
# 3640                   Viniverde
# 3641              Cuevas del Sur
# 4556    Fattoria Giuseppe Savini
# 4557                Paul Cheneau
# ...                          ...
# 128258                Bloomfield
# 128259                  Montelle
# 128260                 BookCliff
# 128261                Chaddsford
# 128262                    Reyter
#
# [397 rows x 13 columns]

# %% [markdown]
# ## Teste Isolado de diferentes levels em groupby

# %%
arrays = [['Falcon', 'Falcon', 'Parrot', 'Parrot'],
           ['Captive', 'Wild', 'Captive', 'Wild']]
index = pd.MultiIndex.from_arrays(arrays, names=('Animal', 'Type'))
df = pd.DataFrame({'Max Speed': [390., 350., 30., 20.]},
                   index=index)
df
#df.groupby(level=0).mean()
#df.groupby(level=1).mean()
# Out:
#                 Max Speed
# Animal Type
# Falcon Captive      390.0
#        Wild         350.0
# Parrot Captive       30.0
#        Wild          20.0

# %% [markdown]
# #### Visualizando a variedade de maior incidência no Mercado

# %%
tipo = reviews.groupby('variety').variety.value_counts()
tipo.idxmax()
# Out:
# 'Pinot Noir'

# %% [markdown]
# #### Caso queiramos pegar o melhor vinho de cada país, independente da província ou demais índices

# %%
melhor_pais = reviews.groupby("country").apply(lambda reviews: reviews.loc[reviews['points'].idxmax()])
melhor_pais.head()
# Out:
# C:\Users\joaoe\AppData\Local\Temp\ipykernel_12892\3793059343.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   melhor_pais = reviews.groupby("country").apply(lambda reviews: reviews.loc[reviews['points'].idxmax()])
#                                        country  \
# country
# Argentina                            Argentina
# Armenia                                Armenia
# Australia                            Australia
# Austria                                Austria
# Bosnia and Herzegovina  Bosnia and Herzegovina
#
#                                                               description  \
# country
# Argentina               If the color doesn't tell the full story, the ...
# Armenia                 Deep salmon in color, this wine offers a bouqu...
# Australia               This wine contains some material over 100 year...
# Austria                 Opulent honey and lemon aromas waft from the g...
# Bosnia and Herzegovina  A mix of red and black fruits pervade on the n...
#
#                                                             designation  \
# country
# Argentina                                              Nicasia Vineyard
# Armenia                                                  Estate Bottled
# Australia                                                          Rare
# Austria                 Zwischen den Seen Nummer 9 Trockenbeerenauslese
# Bosnia and Herzegovina                                              NaN
#
#                         points  price          province    region_1 region_2  \
# country
# Argentina                   97  120.0  Mendoza Province     Mendoza      NaN
# Armenia                     88   15.0           Armenia         NaN      NaN
# Australia                  100  350.0          Victoria  Rutherglen      NaN
# Austria                     98    NaN        Burgenland         NaN      NaN
# Bosnia and Herzegovina      88   12.0            Mostar         NaN      NaN
#
#                               taster_name taster_twitter_handle  \
# country
# Argentina               Michael Schachner           @wineschach
# Armenia                     Mike DeSimone        @worldwineguys
# Australia                  Joe Czerwinski                @JoeCz
# Austria                        Roger Voss            @vossroger
# Bosnia and Herzegovina       Jeff Jenssen        @worldwineguys
#
#                                                                     title  \
# country
# Argentina               Bodega Catena Zapata 2006 Nicasia Vineyard Mal...
# Armenia                       Van Ardi 2015 Estate Bottled Rosé (Armenia)
# Australia               Chambers Rosewood Vineyards NV Rare Muscat (Ru...
# Austria                 Kracher 2008 Zwischen den Seen Nummer 9 Trocke...
# Bosnia and Herzegovina                Winery Čitluk 2011 Blatina (Mostar)
#
#                                variety                       winery
# country
# Argentina                       Malbec         Bodega Catena Zapata
# Armenia                           Rosé                     Van Ardi
# Australia                       Muscat  Chambers Rosewood Vineyards
# Austria                 Welschriesling                      Kracher
# Bosnia and Herzegovina         Blatina                Winery Čitluk

# %% [markdown]
# #### Contagem de avaliações por _sommelier's_

# %%
taster_twitter = reviews.groupby("taster_twitter_handle").taster_twitter_handle.value_counts()
taster_twitter
# Out:
# taster_twitter_handle
# @AnneInVino          3685
# @JoeCz               5147
# @bkfiona               27
# @gordone_cellars     4177
# @kerinokeefe        10776
# @laurbuzz            1835
# @mattkettmann        6332
# @paulgwine           9532
# @suskostrzewa        1085
# @vboone              9537
# @vossroger          25514
# @wawinereport        4966
# @wineschach         15134
# @winewchristina         6
# @worldwineguys       1005
# Name: count, dtype: int64

# %% [markdown]
# #### Melhores pontuações para cada preço de vinhos

# %%
best_rating_per_price = reviews.groupby('price').points.max()
best_rating_per_price.sort_values()
best_rating_per_price
# Out:
# price
# 4.0       86
# 5.0       87
# 6.0       88
# 7.0       91
# 8.0       91
#           ..
# 1900.0    98
# 2000.0    97
# 2013.0    91
# 2500.0    96
# 3300.0    88
# Name: points, Length: 390, dtype: int64

# %%
precos_tipo = reviews.groupby('variety').price.agg(['min','max'])
precos_tipo
# Out:
#               min    max
# variety
# Abouriou     15.0   75.0
# Agiorgitiko  10.0   66.0
# Aglianico     6.0  180.0
# Aidani       27.0   27.0
# Airen         8.0   10.0
# ...           ...    ...
# Zinfandel     5.0  100.0
# Zlahtina     13.0   16.0
# Zweigelt      9.0   70.0
# Çalkarası    19.0   19.0
# Žilavka      15.0   15.0
#
# [707 rows x 2 columns]

# %% [markdown]
# #### Ordenando o último dataframe

# %%
precos_tipo_ord = precos_tipo.sort_values(by=["min"],ascending=False)
precos_tipo_ord
# Out:
#                                   min    max
# variety
# Ramisco                         495.0  495.0
# Terrantez                       236.0  236.0
# Francisa                        160.0  160.0
# Rosenmuskateller                150.0  150.0
# Tinta Negra Mole                112.0  112.0
# ...                               ...    ...
# Roscetto                          NaN    NaN
# Sauvignon Blanc-Sauvignon Gris    NaN    NaN
# Tempranillo-Malbec                NaN    NaN
# Vital                             NaN    NaN
# Zelen                             NaN    NaN
#
# [707 rows x 2 columns]

# %% [markdown]
# #### Média de avaliações dadas por cada _sommelier_

# %%
reviewer_mean_ratings = reviews.groupby('taster_name').points.mean()
reviewer_mean_ratings
# Out:
# taster_name
# Alexander Peartree    85.855422
# Anna Lee C. Iijima    88.415629
# Anne Krebiehl MW      90.562551
# Carrie Dykes          86.395683
# Christina Pickard     87.833333
# Fiona Adams           86.888889
# Jeff Jenssen          88.319756
# Jim Gordon            88.626287
# Joe Czerwinski        88.536235
# Kerin O’Keefe         88.867947
# Lauren Buzzeo         87.739510
# Matt Kettmann         90.008686
# Michael Schachner     86.907493
# Mike DeSimone         89.101167
# Paul Gregutt          89.082564
# Roger Voss            88.708003
# Sean P. Sullivan      88.755739
# Susan Kostrzewa       86.609217
# Virginie Boone        89.213379
# Name: points, dtype: float64

# %% [markdown]
# #### Verificando a combinação de COUNTRY com VARIETY e fazendo uma sumarização
# Usando size(), pois não estou contando valores únicos e sim contabilizando quantidade

# %%
country_variety_counts = reviews.groupby(['country','variety']).size().sort_values(ascending=False)
country_variety_counts
# Out:
# country    variety
# US         Pinot Noir                  9885
#            Cabernet Sauvignon          7315
#            Chardonnay                  6801
# France     Bordeaux-style Red Blend    4725
# Italy      Red Blend                   3624
#                                        ...
# Argentina  Cabernet-Malbec                1
# US         Tinta Madeira                  1
# Italy      Centesimino                    1
#            Catalanesca                    1
#            Carmenère                      1
# Length: 1612, dtype: int64

# %% [markdown]
# #### Verificando quantos são nulos na tabela de preços

# %%
pricenull = reviews[reviews.price.isnull()]
pricenull = len(pricenull)
pricenull
# Out:
# 8996

# %% [markdown]
# #### Contabilização da quantidade de regiões(1)

# %%
reviews_per_region = reviews.region_1.fillna("Unknow").value_counts().sort_values(ascending=False)
reviews_per_region
# Out:
# region_1
# Unknow                                21247
# Napa Valley                            4480
# Columbia Valley (WA)                   4124
# Russian River Valley                   3091
# California                             2629
#                                       ...
# Sonoma-Santa Barbara-Mendocino            1
# Sonoma County-Santa Barbara County        1
# Del Veneto                                1
# Bardolino Superiore                       1
# Paestum                                   1
# Name: count, Length: 1230, dtype: int64

# %% [markdown]
# #### Renomeamento de colunas de DataFrame

# %%
renamed = reviews.rename(columns={'region_1':"region","region_2":"locale"})
renamed.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#                 region             locale         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
reindexed = reviews.rename_axis("wines")
reindexed.head()
# Out:
#         country                                        description  \
# wines
# 0         Italy  Aromas include tropical fruit, broom, brimston...
# 1      Portugal  This is ripe and fruity, a wine that is smooth...
# 2            US  Tart and snappy, the flavors of lime flesh and...
# 3            US  Pineapple rind, lemon pith and orange blossom ...
# 4            US  Much like the regular bottling from 2012, this...
#
#                               designation  points  price           province  \
# wines
# 0                            Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                                Avidagos      87   15.0              Douro
# 2                                     NaN      87   14.0             Oregon
# 3                    Reserve Late Harvest      87   13.0           Michigan
# 4      Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#                   region_1           region_2         taster_name  \
# wines
# 0                     Etna                NaN       Kerin O’Keefe
# 1                      NaN                NaN          Roger Voss
# 2        Willamette Valley  Willamette Valley        Paul Gregutt
# 3      Lake Michigan Shore                NaN  Alexander Peartree
# 4        Willamette Valley  Willamette Valley        Paul Gregutt
#
#       taster_twitter_handle  \
# wines
# 0              @kerinokeefe
# 1                @vossroger
# 2               @paulgwine
# 3                       NaN
# 4               @paulgwine
#
#                                                    title         variety  \
# wines
# 0                      Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1          Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2          Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3      St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4      Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                     winery
# wines
# 0                  Nicosia
# 1      Quinta dos Avidagos
# 2                Rainstorm
# 3               St. Julian
# 4             Sweet Cheeks
